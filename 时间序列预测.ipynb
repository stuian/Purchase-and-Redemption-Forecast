# %% [markdown]
# # 时间序列预测

# %% [markdown]
# 参考资料：
# - [时间序列预测](https://link.csdn.net/?target=https%3A%2F%2Fmp.weixin.qq.com%2Fs%3F__biz%3DMzg3NDUwNTM3MA%3D%3D%26mid%3D2247484974%26idx%3D1%26sn%3Dd841c644fd9289ad5ec8c52a443463a5%26chksm%3Dcecef3dbf9b97acd8a9ededc069851afc00db422cb9be4d155cb2c2a9614b2ee2050dc7ab4d7%26scene%3D178%26cur_album_id%3D1588681516295979011%23rd)
# - [时间序列预测方法总结](https://zhuanlan.zhihu.com/p/67832773)

# %% [markdown]
# 时间序列预测就是利用过去一段时间的数据来预测未来一段时间内的信息。
#
# 分为离散型预测和连续型预测。
#
# 与回归分析预测模型不同，时间序列模型依赖于数值在时间上的先后顺序，同样大小的值改变顺序后输入模型产生的结果是不同的。

# %% [markdown]
# ## 基本规则法

# %% [markdown]
# 以 [IJCAI-17 口碑商家客流量预测比赛](https://tianchi.aliyun.com/competition/entrance/231591/information)为例，介绍规则法（人工提取时序特征,如周期性）。
#
# 主要任务：给定店铺（实体店）过去每天的客流量，预测店铺未来14天每天的客流量。
#
# > 支付数据，客流量数据、交通数据等，具有明显的周期性。

# %% [markdown]
# - [检测周期性](https://www.jianshu.com/p/31e20f00c26f?spm=5176.12282029.0.0.36241491UUhnZE)
#     - 获得周期因子
#     - 设置base

# %% [markdown]
# ![QQ%E6%88%AA%E5%9B%BE20210727230805.png](attachment:QQ%E6%88%AA%E5%9B%BE20210727230805.png)

# %% [markdown]
# ## 传统参数法

# %% [markdown]
# - 拟合时间序列，如移动平均法
# - 多因素组合的参数方法，如AR,MA,ARMA

# %% [markdown]
# > [资金流入流出预测-挑战Baseline](https://blog.csdn.net/ximingren/article/details/79214748) 及 [类似方法](https://blog.csdn.net/weixin_47006934/article/details/113141160)

# %% [markdown]
# ## 时间序列分解

# %% [markdown]
# 拆成受好几种因素的影响：季节性，周期性，趋势和不规则波动等。
#
# - 乘法模型
# - 加法模型

# %% [markdown]
# ## 机器学习方法

# %% [markdown]
# 提前时间特征，构建训练数据集，转化为监督学习。

# %% [markdown]
# - 单步预测
# - 多步预测
# - 多变量预测
#
# > svm/xgboost/逻辑回归/线性回归
